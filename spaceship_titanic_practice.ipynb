# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn   # neural network modules
import torch.optim as optim   # optimization algorithms
import torch.nn.functional as F   # functions without parameters like activation functions
from torch.utils.data import TensorDataset, DataLoader   # dataset management, create batches
import torchvision.datasets as datasets   # standard datasets on pytorch
import torchvision.transforms as transforms   #transform datasets

# PyTorch TensorBoard support
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

# %%
train_dataset = pd.read_csv("train.csv")

print("Full train dataset shape is {}".format(train_dataset.shape))
# Out:
# Full train dataset shape is (8693, 14)

# %%
#examine dataset
train_dataset.head()
train_dataset.describe()
# Out:
#                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8514.000000   8512.000000   8510.000000   8485.000000   8510.000000
# mean     28.827930    224.687617    458.077203    173.729169    311.138778
# std      14.489021    666.717663   1611.489240    604.696458   1136.705535
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      19.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      38.000000     47.000000     76.000000     27.000000     59.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8505.000000
# mean     304.854791
# std     1145.717189
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       46.000000
# max    24133.000000

# %%
#drop id and name columns as they are not important
train_dataset = train_dataset.drop(['PassengerId', 'Name'], axis=1)

# %%
#replace nan values with 0
train_dataset.isnull().sum().sort_values(ascending=False)
train_dataset[['VIP', 'CryoSleep', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck','HomePlanet','Destination']] = train_dataset[['VIP', 'CryoSleep', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck','HomePlanet','Destination']].fillna(value=0)

# %%
#replace strings with numbers
train_dataset['HomePlanet'].unique()
train_dataset['HomePlanet'] = train_dataset['HomePlanet'].replace({'Earth':1, 'Europa':2, 'Mars':3})

train_dataset['Destination'].unique()
train_dataset['Destination'] = train_dataset['Destination'].replace({'TRAPPIST-1e':1, '55 Cancri e':2, 'PSO J318.5-22':3})

# %%
#replace booleans with int
target = 'Transported'
train_dataset[target] = train_dataset[target].astype(int)
train_dataset['VIP'] = train_dataset['VIP'].astype(int)
train_dataset['CryoSleep'] = train_dataset['CryoSleep'].astype(int)

# %%
#replace cabin number with 3 different columns
train_dataset[['Deck', 'Cabin_num', 'Side']] = train_dataset['Cabin'].str.split("/", expand=True)
train_dataset['Deck'].unique()
train_dataset['Cabin_num'].unique()
train_dataset['Cabin_num'].isnull().values.any()
train_dataset['Side'].unique()

train_dataset[['Deck', 'Cabin_num', 'Side']] = train_dataset[['Deck', 'Cabin_num', 'Side']].fillna(value=0)
train_dataset['Deck'] = train_dataset['Deck'].replace({'A':1, 'B':2, 'C':3, 'D':4, 'E':5, 'F':6, 'G':7, 'T':8})
train_dataset['Side'] = train_dataset['Side'].replace({'P':1, 'S':2})
train_dataset['Cabin_num'] = train_dataset['Cabin_num'].astype(int)
train_dataset = train_dataset.drop('Cabin', axis=1)

# %%
train_dataset.head()
# Out:
#    HomePlanet  CryoSleep  Destination   Age  VIP  RoomService  FoodCourt  \
# 0           2          0            1  39.0    0          0.0        0.0
# 1           1          0            1  24.0    0        109.0        9.0
# 2           2          0            1  58.0    1         43.0     3576.0
# 3           2          0            1  33.0    0          0.0     1283.0
# 4           1          0            1  16.0    0        303.0       70.0
#
#    ShoppingMall     Spa  VRDeck  Transported  Deck  Cabin_num  Side
# 0           0.0     0.0     0.0            0     2          0     1
# 1          25.0   549.0    44.0            1     6          0     2
# 2           0.0  6715.0    49.0            0     1          0     2
# 3         371.0  3329.0   193.0            0     1          0     2
# 4         151.0   565.0     2.0            1     6          1     2

# %%
#train and val split
train_df = train_dataset.sample(frac=0.8, random_state=123)
val_df = train_dataset.drop(train_df.index)

# %%
#convert to tensors
train_x = torch.tensor(train_df.drop("Transported", axis=1).values, dtype=torch.float32)
train_y = torch.tensor(train_df["Transported"].values, dtype=torch.float32)
val_x = torch.tensor(val_df.drop("Transported", axis=1).values, dtype=torch.float32)
val_y = torch.tensor(val_df["Transported"].values, dtype=torch.float32)

train_dataset = TensorDataset(train_x, train_y)
val_dataset = TensorDataset(val_x, val_y)
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# %%
# hyperparameters
input_size = train_x.shape[1]
num_classes = 1 #if probability greater than 0.5, then True, if less then False
learning_rate = 0.001  
num_epochs = 300

# %%
class NN(nn.Module):
    def __init__(self, input_size, num_classes):
        super(NN,self).__init__()
        self.fc1 = nn.Linear(input_size, 100)
        self.fc2 = nn.Linear(100,50)
        self.fc3 = nn.Linear(50, num_classes)
        
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = NN(input_size=input_size, num_classes=num_classes).to(device)

criterion = nn.BCEWithLogitsLoss()

optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):   

    for batch_x, batch_y in train_loader:   
        batch_x = batch_x.to(device=device)
        batch_y = batch_y.to(device=device) 
        outputs = model(batch_x) 
        loss = criterion(outputs.squeeze(),batch_y) 
        optimizer.zero_grad()   
        loss.backward()
        optimizer.step()
# Out:
# Epoch 1/300, Loss: nan, Accuracy: 0.4961
# Epoch 2/300, Loss: nan, Accuracy: 0.4957
# Epoch 3/300, Loss: nan, Accuracy: 0.4957
# Epoch 4/300, Loss: nan, Accuracy: 0.4957
# Epoch 5/300, Loss: nan, Accuracy: 0.4957
# Epoch 6/300, Loss: nan, Accuracy: 0.4957
# Epoch 7/300, Loss: nan, Accuracy: 0.4957
# Epoch 8/300, Loss: nan, Accuracy: 0.4957
# Epoch 9/300, Loss: nan, Accuracy: 0.4957
# Epoch 10/300, Loss: nan, Accuracy: 0.4957
# Epoch 11/300, Loss: nan, Accuracy: 0.4957
# Epoch 12/300, Loss: nan, Accuracy: 0.4957
# Epoch 13/300, Loss: nan, Accuracy: 0.4957
# Epoch 14/300, Loss: nan, Accuracy: 0.4957
# Epoch 15/300, Loss: nan, Accuracy: 0.4957
# Epoch 16/300, Loss: nan, Accuracy: 0.4957
# Epoch 17/300, Loss: nan, Accuracy: 0.4957
# Epoch 18/300, Loss: nan, Accuracy: 0.4957
# Epoch 19/300, Loss: nan, Accuracy: 0.4957
# Epoch 20/300, Loss: nan, Accuracy: 0.4957
# Epoch 21/300, Loss: nan, Accuracy: 0.4957
# Epoch 22/300, Loss: nan, Accuracy: 0.4957
# Epoch 23/300, Loss: nan, Accuracy: 0.4957
# Epoch 24/300, Loss: nan, Accuracy: 0.4957
# Epoch 25/300, Loss: nan, Accuracy: 0.4957
# Epoch 26/300, Loss: nan, Accuracy: 0.4957
# Epoch 27/300, Loss: nan, Accuracy: 0.4957
# Epoch 28/300, Loss: nan, Accuracy: 0.4957
# Epoch 29/300, Loss: nan, Accuracy: 0.4957
# Epoch 30/300, Loss: nan, Accuracy: 0.4957
# Epoch 31/300, Loss: nan, Accuracy: 0.4957
# Epoch 32/300, Loss: nan, Accuracy: 0.4957
# Epoch 33/300, Loss: nan, Accuracy: 0.4957
# Epoch 34/300, Loss: nan, Accuracy: 0.4957
# Epoch 35/300, Loss: nan, Accuracy: 0.4957
# Epoch 36/300, Loss: nan, Accuracy: 0.4957
# Epoch 37/300, Loss: nan, Accuracy: 0.4957
# Epoch 38/300, Loss: nan, Accuracy: 0.4957
# Epoch 39/300, Loss: nan, Accuracy: 0.4957
# Epoch 40/300, Loss: nan, Accuracy: 0.4957
# Epoch 41/300, Loss: nan, Accuracy: 0.4957
# Epoch 42/300, Loss: nan, Accuracy: 0.4957
# Epoch 43/300, Loss: nan, Accuracy: 0.4957
# Epoch 44/300, Loss: nan, Accuracy: 0.4957
# Epoch 45/300, Loss: nan, Accuracy: 0.4957
# Epoch 46/300, Loss: nan, Accuracy: 0.4957
# Epoch 47/300, Loss: nan, Accuracy: 0.4957
# Epoch 48/300, Loss: nan, Accuracy: 0.4957
# Epoch 49/300, Loss: nan, Accuracy: 0.4957
# Epoch 50/300, Loss: nan, Accuracy: 0.4957
# Epoch 51/300, Loss: nan, Accuracy: 0.4957
# Epoch 52/300, Loss: nan, Accuracy: 0.4957
# Epoch 53/300, Loss: nan, Accuracy: 0.4957
# Epoch 54/300, Loss: nan, Accuracy: 0.4957
# Epoch 55/300, Loss: nan, Accuracy: 0.4957
# Epoch 56/300, Loss: nan, Accuracy: 0.4957
# Epoch 57/300, Loss: nan, Accuracy: 0.4957
# Epoch 58/300, Loss: nan, Accuracy: 0.4957
# Epoch 59/300, Loss: nan, Accuracy: 0.4957
# Epoch 60/300, Loss: nan, Accuracy: 0.4957
# Epoch 61/300, Loss: nan, Accuracy: 0.4957
# Epoch 62/300, Loss: nan, Accuracy: 0.4957
# Epoch 63/300, Loss: nan, Accuracy: 0.4957
# Epoch 64/300, Loss: nan, Accuracy: 0.4957
# Epoch 65/300, Loss: nan, Accuracy: 0.4957
# Epoch 66/300, Loss: nan, Accuracy: 0.4957
# Epoch 67/300, Loss: nan, Accuracy: 0.4957
# Epoch 68/300, Loss: nan, Accuracy: 0.4957
# Epoch 69/300, Loss: nan, Accuracy: 0.4957
# Epoch 70/300, Loss: nan, Accuracy: 0.4957
# Epoch 71/300, Loss: nan, Accuracy: 0.4957
# Epoch 72/300, Loss: nan, Accuracy: 0.4957
# Epoch 73/300, Loss: nan, Accuracy: 0.4957
# Epoch 74/300, Loss: nan, Accuracy: 0.4957
# Epoch 75/300, Loss: nan, Accuracy: 0.4957
# Epoch 76/300, Loss: nan, Accuracy: 0.4957
# Epoch 77/300, Loss: nan, Accuracy: 0.4957
# Epoch 78/300, Loss: nan, Accuracy: 0.4957
# Epoch 79/300, Loss: nan, Accuracy: 0.4957
# Epoch 80/300, Loss: nan, Accuracy: 0.4957
# Epoch 81/300, Loss: nan, Accuracy: 0.4957
# Epoch 82/300, Loss: nan, Accuracy: 0.4957
# Epoch 83/300, Loss: nan, Accuracy: 0.4957
# Epoch 84/300, Loss: nan, Accuracy: 0.4957
# Epoch 85/300, Loss: nan, Accuracy: 0.4957
# Epoch 86/300, Loss: nan, Accuracy: 0.4957
# Epoch 87/300, Loss: nan, Accuracy: 0.4957
# Epoch 88/300, Loss: nan, Accuracy: 0.4957
# Epoch 89/300, Loss: nan, Accuracy: 0.4957
# Epoch 90/300, Loss: nan, Accuracy: 0.4957
# Epoch 91/300, Loss: nan, Accuracy: 0.4957
# Epoch 92/300, Loss: nan, Accuracy: 0.4957
# Epoch 93/300, Loss: nan, Accuracy: 0.4957
# Epoch 94/300, Loss: nan, Accuracy: 0.4957
# Epoch 95/300, Loss: nan, Accuracy: 0.4957
# Epoch 96/300, Loss: nan, Accuracy: 0.4957
# Epoch 97/300, Loss: nan, Accuracy: 0.4957
# Epoch 98/300, Loss: nan, Accuracy: 0.4957
# Epoch 99/300, Loss: nan, Accuracy: 0.4957
# Epoch 100/300, Loss: nan, Accuracy: 0.4957
# Epoch 101/300, Loss: nan, Accuracy: 0.4957
# Epoch 102/300, Loss: nan, Accuracy: 0.4957
# Epoch 103/300, Loss: nan, Accuracy: 0.4957
# Epoch 104/300, Loss: nan, Accuracy: 0.4957
# Epoch 105/300, Loss: nan, Accuracy: 0.4957
# Epoch 106/300, Loss: nan, Accuracy: 0.4957
# Epoch 107/300, Loss: nan, Accuracy: 0.4957
# Epoch 108/300, Loss: nan, Accuracy: 0.4957
# Epoch 109/300, Loss: nan, Accuracy: 0.4957
# Epoch 110/300, Loss: nan, Accuracy: 0.4957
# Epoch 111/300, Loss: nan, Accuracy: 0.4957
# Epoch 112/300, Loss: nan, Accuracy: 0.4957
# Epoch 113/300, Loss: nan, Accuracy: 0.4957
# Epoch 114/300, Loss: nan, Accuracy: 0.4957
# Epoch 115/300, Loss: nan, Accuracy: 0.4957
# Epoch 116/300, Loss: nan, Accuracy: 0.4957
# Epoch 117/300, Loss: nan, Accuracy: 0.4957
# Epoch 118/300, Loss: nan, Accuracy: 0.4957
# Epoch 119/300, Loss: nan, Accuracy: 0.4957
# Epoch 120/300, Loss: nan, Accuracy: 0.4957
# Epoch 121/300, Loss: nan, Accuracy: 0.4957
# Epoch 122/300, Loss: nan, Accuracy: 0.4957
# Epoch 123/300, Loss: nan, Accuracy: 0.4957
# Epoch 124/300, Loss: nan, Accuracy: 0.4957
# Epoch 125/300, Loss: nan, Accuracy: 0.4957
# Epoch 126/300, Loss: nan, Accuracy: 0.4957
# Epoch 127/300, Loss: nan, Accuracy: 0.4957
# Epoch 128/300, Loss: nan, Accuracy: 0.4957
# Epoch 129/300, Loss: nan, Accuracy: 0.4957
# Epoch 130/300, Loss: nan, Accuracy: 0.4957
# Epoch 131/300, Loss: nan, Accuracy: 0.4957
# Epoch 132/300, Loss: nan, Accuracy: 0.4957
# Epoch 133/300, Loss: nan, Accuracy: 0.4957
# Epoch 134/300, Loss: nan, Accuracy: 0.4957
# Epoch 135/300, Loss: nan, Accuracy: 0.4957
# Epoch 136/300, Loss: nan, Accuracy: 0.4957
# Epoch 137/300, Loss: nan, Accuracy: 0.4957
# Epoch 138/300, Loss: nan, Accuracy: 0.4957
# Epoch 139/300, Loss: nan, Accuracy: 0.4957
# Epoch 140/300, Loss: nan, Accuracy: 0.4957
# Epoch 141/300, Loss: nan, Accuracy: 0.4957
# Epoch 142/300, Loss: nan, Accuracy: 0.4957
# Epoch 143/300, Loss: nan, Accuracy: 0.4957
# Epoch 144/300, Loss: nan, Accuracy: 0.4957
# Epoch 145/300, Loss: nan, Accuracy: 0.4957
# Epoch 146/300, Loss: nan, Accuracy: 0.4957
# Epoch 147/300, Loss: nan, Accuracy: 0.4957
# Epoch 148/300, Loss: nan, Accuracy: 0.4957
# Epoch 149/300, Loss: nan, Accuracy: 0.4957
# Epoch 150/300, Loss: nan, Accuracy: 0.4957
# Epoch 151/300, Loss: nan, Accuracy: 0.4957
# Epoch 152/300, Loss: nan, Accuracy: 0.4957
# Epoch 153/300, Loss: nan, Accuracy: 0.4957
# Epoch 154/300, Loss: nan, Accuracy: 0.4957
# Epoch 155/300, Loss: nan, Accuracy: 0.4957
# Epoch 156/300, Loss: nan, Accuracy: 0.4957
# Epoch 157/300, Loss: nan, Accuracy: 0.4957
# Epoch 158/300, Loss: nan, Accuracy: 0.4957
# Epoch 159/300, Loss: nan, Accuracy: 0.4957
# Epoch 160/300, Loss: nan, Accuracy: 0.4957
# Epoch 161/300, Loss: nan, Accuracy: 0.4957
# Epoch 162/300, Loss: nan, Accuracy: 0.4957
# Epoch 163/300, Loss: nan, Accuracy: 0.4957
# Epoch 164/300, Loss: nan, Accuracy: 0.4957
# Epoch 165/300, Loss: nan, Accuracy: 0.4957
# Epoch 166/300, Loss: nan, Accuracy: 0.4957
# Epoch 167/300, Loss: nan, Accuracy: 0.4957
# Epoch 168/300, Loss: nan, Accuracy: 0.4957
# Epoch 169/300, Loss: nan, Accuracy: 0.4957
# Epoch 170/300, Loss: nan, Accuracy: 0.4957
# Epoch 171/300, Loss: nan, Accuracy: 0.4957
# Epoch 172/300, Loss: nan, Accuracy: 0.4957
# Epoch 173/300, Loss: nan, Accuracy: 0.4957
# Epoch 174/300, Loss: nan, Accuracy: 0.4957
# Epoch 175/300, Loss: nan, Accuracy: 0.4957
# Epoch 176/300, Loss: nan, Accuracy: 0.4957
# Epoch 177/300, Loss: nan, Accuracy: 0.4957
# Epoch 178/300, Loss: nan, Accuracy: 0.4957
# Epoch 179/300, Loss: nan, Accuracy: 0.4957
# Epoch 180/300, Loss: nan, Accuracy: 0.4957
# Epoch 181/300, Loss: nan, Accuracy: 0.4957
# Epoch 182/300, Loss: nan, Accuracy: 0.4957
# Epoch 183/300, Loss: nan, Accuracy: 0.4957
# Epoch 184/300, Loss: nan, Accuracy: 0.4957
# Epoch 185/300, Loss: nan, Accuracy: 0.4957
# Epoch 186/300, Loss: nan, Accuracy: 0.4957
# Epoch 187/300, Loss: nan, Accuracy: 0.4957
# Epoch 188/300, Loss: nan, Accuracy: 0.4957
# Epoch 189/300, Loss: nan, Accuracy: 0.4957
# Epoch 190/300, Loss: nan, Accuracy: 0.4957
# Epoch 191/300, Loss: nan, Accuracy: 0.4957
# Epoch 192/300, Loss: nan, Accuracy: 0.4957
# Epoch 193/300, Loss: nan, Accuracy: 0.4957
# Epoch 194/300, Loss: nan, Accuracy: 0.4957
# Epoch 195/300, Loss: nan, Accuracy: 0.4957
# Epoch 196/300, Loss: nan, Accuracy: 0.4957
# Epoch 197/300, Loss: nan, Accuracy: 0.4957
# Epoch 198/300, Loss: nan, Accuracy: 0.4957
# Epoch 199/300, Loss: nan, Accuracy: 0.4957
# Epoch 200/300, Loss: nan, Accuracy: 0.4957
# Epoch 201/300, Loss: nan, Accuracy: 0.4957
# Epoch 202/300, Loss: nan, Accuracy: 0.4957
# Epoch 203/300, Loss: nan, Accuracy: 0.4957
# Epoch 204/300, Loss: nan, Accuracy: 0.4957
# Epoch 205/300, Loss: nan, Accuracy: 0.4957
# Epoch 206/300, Loss: nan, Accuracy: 0.4957
# Epoch 207/300, Loss: nan, Accuracy: 0.4957
# Epoch 208/300, Loss: nan, Accuracy: 0.4957
# Epoch 209/300, Loss: nan, Accuracy: 0.4957
# Epoch 210/300, Loss: nan, Accuracy: 0.4957
# Epoch 211/300, Loss: nan, Accuracy: 0.4957
# Epoch 212/300, Loss: nan, Accuracy: 0.4957
# Epoch 213/300, Loss: nan, Accuracy: 0.4957
# Epoch 214/300, Loss: nan, Accuracy: 0.4957
# Epoch 215/300, Loss: nan, Accuracy: 0.4957
# Epoch 216/300, Loss: nan, Accuracy: 0.4957
# Epoch 217/300, Loss: nan, Accuracy: 0.4957
# Epoch 218/300, Loss: nan, Accuracy: 0.4957
# Epoch 219/300, Loss: nan, Accuracy: 0.4957
# Epoch 220/300, Loss: nan, Accuracy: 0.4957
# Epoch 221/300, Loss: nan, Accuracy: 0.4957
# Epoch 222/300, Loss: nan, Accuracy: 0.4957
# Epoch 223/300, Loss: nan, Accuracy: 0.4957
# Epoch 224/300, Loss: nan, Accuracy: 0.4957
# Epoch 225/300, Loss: nan, Accuracy: 0.4957
# Epoch 226/300, Loss: nan, Accuracy: 0.4957
# Epoch 227/300, Loss: nan, Accuracy: 0.4957
# Epoch 228/300, Loss: nan, Accuracy: 0.4957
# Epoch 229/300, Loss: nan, Accuracy: 0.4957
# Epoch 230/300, Loss: nan, Accuracy: 0.4957
# Epoch 231/300, Loss: nan, Accuracy: 0.4957
# Epoch 232/300, Loss: nan, Accuracy: 0.4957
# Epoch 233/300, Loss: nan, Accuracy: 0.4957
# Epoch 234/300, Loss: nan, Accuracy: 0.4957
# Epoch 235/300, Loss: nan, Accuracy: 0.4957
# Epoch 236/300, Loss: nan, Accuracy: 0.4957
# Epoch 237/300, Loss: nan, Accuracy: 0.4957
# Epoch 238/300, Loss: nan, Accuracy: 0.4957
# Epoch 239/300, Loss: nan, Accuracy: 0.4957
# Epoch 240/300, Loss: nan, Accuracy: 0.4957
# Epoch 241/300, Loss: nan, Accuracy: 0.4957
# Epoch 242/300, Loss: nan, Accuracy: 0.4957
# Epoch 243/300, Loss: nan, Accuracy: 0.4957
# Epoch 244/300, Loss: nan, Accuracy: 0.4957
# Epoch 245/300, Loss: nan, Accuracy: 0.4957
# Epoch 246/300, Loss: nan, Accuracy: 0.4957
# Epoch 247/300, Loss: nan, Accuracy: 0.4957
# Epoch 248/300, Loss: nan, Accuracy: 0.4957
# Epoch 249/300, Loss: nan, Accuracy: 0.4957
# Epoch 250/300, Loss: nan, Accuracy: 0.4957
# Epoch 251/300, Loss: nan, Accuracy: 0.4957
# Epoch 252/300, Loss: nan, Accuracy: 0.4957
# Epoch 253/300, Loss: nan, Accuracy: 0.4957
# Epoch 254/300, Loss: nan, Accuracy: 0.4957
# Epoch 255/300, Loss: nan, Accuracy: 0.4957
# Epoch 256/300, Loss: nan, Accuracy: 0.4957
# Epoch 257/300, Loss: nan, Accuracy: 0.4957
# Epoch 258/300, Loss: nan, Accuracy: 0.4957
# Epoch 259/300, Loss: nan, Accuracy: 0.4957
# Epoch 260/300, Loss: nan, Accuracy: 0.4957
# Epoch 261/300, Loss: nan, Accuracy: 0.4957
# Epoch 262/300, Loss: nan, Accuracy: 0.4957
# Epoch 263/300, Loss: nan, Accuracy: 0.4957
# Epoch 264/300, Loss: nan, Accuracy: 0.4957
# Epoch 265/300, Loss: nan, Accuracy: 0.4957
# Epoch 266/300, Loss: nan, Accuracy: 0.4957
# Epoch 267/300, Loss: nan, Accuracy: 0.4957
# Epoch 268/300, Loss: nan, Accuracy: 0.4957
# Epoch 269/300, Loss: nan, Accuracy: 0.4957
# Epoch 270/300, Loss: nan, Accuracy: 0.4957
# Epoch 271/300, Loss: nan, Accuracy: 0.4957
# Epoch 272/300, Loss: nan, Accuracy: 0.4957
# Epoch 273/300, Loss: nan, Accuracy: 0.4957
# Epoch 274/300, Loss: nan, Accuracy: 0.4957
# Epoch 275/300, Loss: nan, Accuracy: 0.4957
# Epoch 276/300, Loss: nan, Accuracy: 0.4957
# Epoch 277/300, Loss: nan, Accuracy: 0.4957
# Epoch 278/300, Loss: nan, Accuracy: 0.4957
# Epoch 279/300, Loss: nan, Accuracy: 0.4957
# Epoch 280/300, Loss: nan, Accuracy: 0.4957
# Epoch 281/300, Loss: nan, Accuracy: 0.4957
# Epoch 282/300, Loss: nan, Accuracy: 0.4957
# Epoch 283/300, Loss: nan, Accuracy: 0.4957
# Epoch 284/300, Loss: nan, Accuracy: 0.4957
# Epoch 285/300, Loss: nan, Accuracy: 0.4957
# Epoch 286/300, Loss: nan, Accuracy: 0.4957
# Epoch 287/300, Loss: nan, Accuracy: 0.4957
# Epoch 288/300, Loss: nan, Accuracy: 0.4957
# Epoch 289/300, Loss: nan, Accuracy: 0.4957
# Epoch 290/300, Loss: nan, Accuracy: 0.4957
# Epoch 291/300, Loss: nan, Accuracy: 0.4957
# Epoch 292/300, Loss: nan, Accuracy: 0.4957
# Epoch 293/300, Loss: nan, Accuracy: 0.4957
# Epoch 294/300, Loss: nan, Accuracy: 0.4957
# Epoch 295/300, Loss: nan, Accuracy: 0.4957
# Epoch 296/300, Loss: nan, Accuracy: 0.4957
# Epoch 297/300, Loss: nan, Accuracy: 0.4957
# Epoch 298/300, Loss: nan, Accuracy: 0.4957
# Epoch 299/300, Loss: nan, Accuracy: 0.4957
# Epoch 300/300, Loss: nan, Accuracy: 0.4957

# %%
def check_accuracy(loader,model): 
    if loader == train_loader: 
        print("checking accuracy on training data")
    else:
        print("checking accuracy on test data")
    num_correct = 0
    num_samples = 0
    model.eval() 
    
    with torch.no_grad(): 
        for x,y in loader:
            x= x.to(device=device)
            y= y.to(device=device)
            
            outputs = model(x)
            probs = torch.sigmoid(outputs).squeeze() #maps any input value to a probability value between 0 and 1
            preds = (probs > 0.5).to(torch.float32) #applies a threshold of 0.5 to the predicted probabilities, then converts boolean to float
            
            num_correct += (preds == y).sum()
            num_samples += x.shape[0]
            
        print(f'{num_correct} / {num_samples} with accuracy {float(num_correct)/float(num_samples)*100:.2f}')   #2dp
        
    model.train()

# %%
check_accuracy(train_loader,model)
check_accuracy(val_loader,model)
# Out:
# checking accuracy on training data
# 3447 / 6954 with accuracy 49.57
# checking accuracy on test data
# 868 / 1739 with accuracy 49.91
